# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan-1104/ML-1/blob/main/Vector_Operations_in_Python_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([2,3])
b = np.array([4,5])
a_dot_b = np.dot(a,b)

# %%
print(a_dot_b)
# Out:
# 23

# %%
c = np.array([40, 20, 35])

d = np.array([53, 24, 68])

c_dot_d = np.dot(c, d)

# %%
print(c_dot_d)
# Out:
# 4980

# %% [markdown]
# Cross Product

# %%
a = np.array([2, 3])

b = np.array([4, 4])

a_cross_b = np.cross(a, b)
# Out:
# /tmp/ipykernel_11610/1135455818.py:5: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   a_cross_b = np.cross(a, b)

# %%
print(a_cross_b)
# Out:
# -4

# %%
c = np.array([5, 10, 20])

d = np.array([18, 32, 50])

c_cross_d = np.cross(c, d)

# %%
print(c_cross_d)
# Out:
# [-140  110  -20]

# %% [markdown]
# Projection of "a" vector on "v" vector

# %%
a = np.array([2, 5])

v = np.array([8, -6])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v

print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [-1.12  0.84]

# %%
a = np.array([23, 45, 62])

v = np.array([45, 82, 67])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v

print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [30.18242937 54.99909352 44.93828373]
