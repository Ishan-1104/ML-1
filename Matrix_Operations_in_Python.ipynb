# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan-1104/ML-1/blob/main/Matrix_Operations_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Matrix Addition

# %%
A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

# %%
print(A)
# Out:
# [[2 3]
#  [4 5]]

# %%
print(B)
# Out:
# [[6 7]
#  [8 9]]

# %%
sum = A+B

# %%
print(sum)
# Out:
# [[ 8 10]
#  [12 14]]

# %%
matrix_1 = np.random.randint(10, size=(3,3))
matrix_2 = np.random.randint(20, size=(3,3))

# %%
print(matrix_1)
# Out:
# [[1 3 0]
#  [5 2 1]
#  [1 0 4]]

# %%
print(matrix_2)
# Out:
# [[ 7 18 19]
#  [14 19  8]
#  [10 18  7]]

# %%
matrix_1.shape
# Out:
# (3, 3)

# %%
matrix_2.shape
# Out:
# (3, 3)

# %%
sum2 = matrix_1 + matrix_2

# %%
print(sum2)
# Out:
# [[ 8 21 19]
#  [19 21  9]
#  [11 18 11]]

# %% [markdown]
# Matrix **Subtraction**

# %%
A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

# %%
diff = A-B

# %%
print(diff)
# Out:
# [[-4 -4]
#  [-4 -4]]

# %%
matrix_1 = np.random.randint(10, size=(3,3))
matrix_2 = np.random.randint(20, size=(3,3))

# %%
print(matrix_1)
# Out:
# [[2 6 3]
#  [5 3 2]
#  [0 6 5]]

# %%
print(matrix_2)
# Out:
# [[ 2 12  0]
#  [13  7 18]
#  [ 6  5 18]]

# %%
diff2 = np.subtract(matrix_1, matrix_2)

# %%
print(diff2)
# Out:
# [[  0  -6   3]
#  [ -8  -4 -16]
#  [ -6   1 -13]]

# %% [markdown]
# Multiplying a matrix by a scalar

# %%
x = 5
y = np.random.randint(10, size=(4,4))

print(y)
# Out:
# [[3 9 5 3]
#  [7 2 5 0]
#  [3 9 2 5]
#  [8 1 3 3]]

# %%
product = np.multiply(x,y)

# %%
print(product)
# Out:
# [[15 45 25 15]
#  [35 10 25  0]
#  [15 45 10 25]
#  [40  5 15 15]]

# %% [markdown]
# Multiplying 2 Matrices

# %%
matrix_3 = np.random.randint(5, size=(3,3))
matrix_4 = np.random.randint(5, size=(3,4))

# %%
print(matrix_3)
# Out:
# [[4 0 2]
#  [3 4 4]
#  [3 4 1]]

# %%
print(matrix_4)
# Out:
# [[0 3 4 2]
#  [4 3 3 2]
#  [3 3 2 2]]

# %%
product = np.dot(matrix_3, matrix_4)

# %%
print(product)
# Out:
# [[ 6 18 20 12]
#  [28 33 32 22]
#  [19 24 26 16]]
